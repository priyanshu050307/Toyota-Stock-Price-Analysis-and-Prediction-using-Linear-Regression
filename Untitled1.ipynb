# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv('final.csv')

print(df.head())
print(df.describe())
print(df.shape)
print(df.info())
print(df.isnull().sum())

df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(by='Date')

df['Open_prev'] = df['Open'].shift(1)
df['Volume_prev'] = df['Volume'].shift(1)
df['RSI_prev'] = df['RSI'].shift(1)
df['MACD_prev'] = df['MACD'].shift(1)
df['Volatility_10_prev'] = df['Volatility_10'].shift(1)

df = df.dropna()

X = df[['Open_prev','Volume_prev','RSI_prev','MACD_prev','Volatility_10_prev']]
y = df['Close']

split = int(len(df)*0.8)
X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("MSE:", mean_squared_error(y_test,y_pred))
print("R2:",r2_score(y_test,y_pred))
coeff_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})

print(coeff_df)

last_row = df.iloc[-1]
input_data = [[
    last_row['Open'],
    last_row['Volume'],
    last_row['RSI'],
    last_row['MACD'],
    last_row['Volatility_10']
]]

predicted_price = model.predict(input_data)
print("Predicted Next Day Close:",predicted_price[0])
# Out:
#         Date     Close      High       Low      Open  Volume    Return  \
# 0  5/29/1980  2.181837  2.181837  2.181837  2.181837       0  0.000000
# 1  5/30/1980  2.174467  2.203951  2.174467  2.181838    6540 -0.003378
# 2   6/2/1980  2.181837  2.211321  2.181837  2.181837     934  0.003390
# 3   6/3/1980  2.181837  2.211321  2.181837  2.181837   18686  0.000000
# 4   6/4/1980  2.189208  2.218692  2.189208  2.189208    8409  0.003378
#
#    Volatility_10  Volatility_30        RSI      MACD  MACD_Signal
# 0       0.012999       0.010338  68.571347  0.063000     0.063758
# 1       0.013104       0.010406  65.714212  0.060108     0.063028
# 2       0.009428       0.009725  60.000000  0.057746     0.061972
# 3       0.009266       0.009725  60.000000  0.055237     0.060625
# 4       0.006957       0.009686  61.290296  0.053229     0.059146
#               Close          High           Low          Open        Volume  \
# count  11552.000000  11552.000000  11552.000000  11552.000000  1.155200e+04
# mean      57.020490     57.349782     56.689348     57.027815  2.194762e+05
# std       51.946029     52.221970     51.629956     51.937816  3.845098e+05
# min        2.012303      2.027782      2.012303      2.020042  0.000000e+00
# 25%       15.797022     15.900275     15.797022     15.848655  1.423700e+04
# 50%       41.775394     42.049883     41.433696     41.739893  1.064000e+05
# 75%       86.308844     86.735801     85.900895     86.417545  3.034250e+05
# max      248.289993    248.899994    245.869995    246.960007  1.858270e+07
#
#              Return  Volatility_10  Volatility_30           RSI          MACD  \
# count  11552.000000   11552.000000   11552.000000  11552.000000  11552.000000
# mean       0.000559       0.016004       0.016641     51.601921      0.133592
# std        0.018306       0.009193       0.007798     16.960290      1.236128
# min       -0.165236       0.002690       0.004714      0.000000     -9.370294
# 25%       -0.008770       0.010224       0.011603     39.823615     -0.222001
# 50%        0.000000       0.014026       0.015011     50.943452      0.037626
# 75%        0.009195       0.019049       0.019459     63.455824      0.437187
# max        0.193549       0.107594       0.065971    100.000000     10.376403
#
#         MACD_Signal
# count  11552.000000
# mean       0.135709
# std        1.148693
# min       -7.869167
# 25%       -0.201937
# 50%        0.036685
# 75%        0.436858
# max        9.750075
# (11552, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           11552 non-null  object
#  1   Close          11552 non-null  float64
#  2   High           11552 non-null  float64
#  3   Low            11552 non-null  float64
#  4   Open           11552 non-null  float64
#  5   Volume         11552 non-null  int64
#  6   Return         11552 non-null  float64
#  7   Volatility_10  11552 non-null  float64
#  8   Volatility_30  11552 non-null  float64
#  9   RSI            11552 non-null  float64
#  10  MACD           11552 non-null  float64
#  11  MACD_Signal    11552 non-null  float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 1.1+ MB
# None
# Date             0
# Close            0
# High             0
# Low              0
# Open             0
# Volume           0
# Return           0
# Volatility_10    0
# Volatility_30    0
# RSI              0
# MACD             0
# MACD_Signal      0
# dtype: int64
# MSE: 6.544655455365909
# R2: 0.9957414327721386
#               Feature   Coefficient
# 0           Open_prev  9.999276e-01
# 1         Volume_prev -1.351899e-08
# 2            RSI_prev  2.610635e-03
# 3           MACD_prev -3.818441e-02
# 4  Volatility_10_prev -1.096527e+00
# Predicted Next Day Close: 205.68978079928272
# C:\Users\Hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
